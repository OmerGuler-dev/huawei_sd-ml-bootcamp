# %% [markdown]
# # VERİ BİLİMİ EĞİTİMİ

# %% [markdown]
# #Veri Setini Tanıma
#
# Amaç:
#   1. Veri setinin genel yapısını tanımak ve temel özelliklerini incelemek
#   2. Veri analizi öncesi gerekli ilk kontrolleri uygulamak
#
# Adımlar:
#   1. Veri Setini yüklemek
#   2. veri setinin ilk ve son satırlarını incele
#   3. Veri setinin boyutunu ve sütunları kontrol etmek
#   4. veri setinin genel bilgisini incele
#   5. özet istatistikleri görüntüle
#   6. Veri Tiplerini kontrol et
#   7. Sayısal Ve Kategorik sütunları ayırmak
#   8. Benzersiz(unique) sayılarını incelemek

# %%
import pandas as pd

# %%
# 1 Veri Setini Yükleme
df = pd.read_csv("e_ticaret_veri_seti.csv")

# %%
# 2 Veri Setinin ilk ve son satırlarını incele
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# 1        Spor           Dambıl Seti     2      1475.15           0.10
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 3       Kitap          Girişimcilik     5       194.78           0.00
# 4  Elektronik             Powerbank     3       841.80           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          29.9     Banka Kartı          VIP            4.0            1.0
# 2          29.9     Kredi Kartı       Mevcut            6.0            2.0
# 3          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 4          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar
# 0       Hayır            0.220        443.68
# 1       Hayır            0.361       2685.17
# 2       Hayır            0.348        304.47
# 3       Hayır            0.250       1023.80
# 4       Hayır            0.280       2439.03

# %%
df.tail()
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 1423  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul            Marmara
# 1424  SIP101193    MUS1297  2025-11-06 08:17:00  Gaziantep  Güneydoğu Anadolu
# 1425  SIP101210    MUS1122  2025-03-07 09:07:00        NaN            Marmara
# 1426  SIP101060    MUS1189  2025-04-19 21:52:00    Kocaeli            Marmara
# 1427  SIP100642    MUS1289  2024-09-22 16:36:00     Ankara         İç Anadolu
#
#         kategori         urun_adi  adet  birim_fiyat  indirim_orani  \
# 1423        Spor        Yoga Matı     1       772.23           0.00
# 1424        Spor            Suluk     2       187.03           0.00
# 1425  Elektronik           Webcam     4       894.47           0.10
# 1426       Kitap  Veri Bilimi 101     2       248.55           0.05
# 1427    Kozmetik      Güneş Kremi     1       424.84           0.20
#
#       kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 1423          29.9     Kredi Kartı       Mevcut            3.0            2.0
# 1424          59.9     Kredi Kartı         Yeni            2.0            4.0
# 1425          49.9     Kredi Kartı       Mevcut            3.0            5.0
# 1426          59.9     banka karti         Yeni            4.0            3.0
# 1427           0.0  Dijital Cüzdan         Yeni            2.0            4.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar
# 1423       Hayır            0.275        802.13
# 1424        Evet            0.243        433.96
# 1425       Hayır            0.355       3269.99
# 1426       Hayır            0.373        532.14
# 1427       Hayır            0.317        339.87

# %%
# 3 veri setinin boyutunu ve sütunlarını kontrol etme , df.shape[] = (satir_sayisi , sütun sayısı)
satir_sayisi = df.shape[0]
satir_sayisi
# Out:
# 1428

# %%
sutun_sayisi = df.shape[1]
sutun_sayisi
# Out:
# 18

# %%
#sütun isimleri
for i,sutun in enumerate(df.columns,start = 1):
  print(f"{i} , {sutun}")
# Out:
# 1 , siparis_id
# 2 , musteri_id
# 3 , siparis_tarihi
# 4 , sehir
# 5 , bolge
# 6 , kategori
# 7 , urun_adi
# 8 , adet
# 9 , birim_fiyat
# 10 , indirim_orani
# 11 , kargo_ucreti
# 12 , odeme_turu
# 13 , musteri_tipi
# 14 , teslimat_gunu
# 15 , musteri_puani
# 16 , iade_durumu
# 17 , kar_marji_orani
# 18 , toplam_tutar

# %%
# 4. veri setinin genel bilgisini inceleme
df.info() # sütun isimlerini , veri tiplerini , missing value bilgisini verir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   siparis_id       1428 non-null   object
#  1   musteri_id       1428 non-null   object
#  2   siparis_tarihi   1428 non-null   object
#  3   sehir            1403 non-null   object
#  4   bolge            1428 non-null   object
#  5   kategori         1428 non-null   object
#  6   urun_adi         1428 non-null   object
#  7   adet             1428 non-null   int64
#  8   birim_fiyat      1428 non-null   float64
#  9   indirim_orani    1412 non-null   float64
#  10  kargo_ucreti     1428 non-null   float64
#  11  odeme_turu       1393 non-null   object
#  12  musteri_tipi     1386 non-null   object
#  13  teslimat_gunu    1400 non-null   float64
#  14  musteri_puani    1372 non-null   float64
#  15  iade_durumu      1428 non-null   object
#  16  kar_marji_orani  1428 non-null   float64
#  17  toplam_tutar     1428 non-null   float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 200.9+ KB

# %%
# 5. Özet istatistikleri görüntüleme
df.describe() #sayısal sütunlar için temel istatistikler
# Out:
#               adet   birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# count  1428.000000   1428.000000    1412.000000   1428.000000    1400.000000
# mean      2.136555    658.477654       0.052054     39.725140       3.370714
# std       2.015770   1042.414639       0.060115     14.185017       1.825990
# min       1.000000     93.110000       0.000000      0.000000       1.000000
# 25%       1.000000    199.185000       0.000000     29.900000       2.000000
# 50%       2.000000    287.120000       0.050000     39.900000       3.000000
# 75%       3.000000    819.177500       0.100000     49.900000       4.000000
# max      38.000000  18145.230000       0.200000     59.900000      31.000000
#
#        musteri_puani  kar_marji_orani  toplam_tutar
# count    1372.000000      1428.000000   1428.000000
# mean        4.002187         0.302799   1370.590336
# std         1.096707         0.069795   2961.689500
# min         0.000000         0.180000     89.680000
# 25%         3.000000         0.244750    323.855000
# 50%         4.000000         0.305000    669.135000
# 75%         5.000000         0.362000   1390.950000
# max         7.000000         0.420000  63870.200000

# %%
# 6. Veri tiplerini kontrol etme
df.dtypes
# Out:
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
# 7 . Sayısal ve Kategorik Sütunların Ayrılması

sayisal_sutunlar = df.select_dtypes(include =["int64", "float64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
#kategorik sütunlar
kategorik_sutunlar = df.select_dtypes(include =[object]).columns
kategorik_sutunlar
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'odeme_turu', 'musteri_tipi', 'iade_durumu'],
#       dtype='object')

# %%
# 8. Benzersiz Unique değerleri inceleme
for sutun in df.columns:
  print(f"{sutun}: {df[sutun].nunique}")
# Out:
# siparis_id: <bound method IndexOpsMixin.nunique of 0       SIP101125
# 1       SIP100837
# 2       SIP100050
# 3       SIP100263
# 4       SIP100707
#           ...
# 1423    SIP101093
# 1424    SIP101193
# 1425    SIP101210
# 1426    SIP101060
# 1427    SIP100642
# Name: siparis_id, Length: 1428, dtype: object>
# musteri_id: <bound method IndexOpsMixin.nunique of 0       MUS1391
# 1       MUS1347
# 2       MUS1066
# 3       MUS1008
# 4       MUS1291
#          ...
# 1423    MUS1187
# 1424    MUS1297
# 1425    MUS1122
# 1426    MUS1189
# 1427    MUS1289
# Name: musteri_id, Length: 1428, dtype: object>
# siparis_tarihi: <bound method IndexOpsMixin.nunique of 0       2024-01-13 17:06:00
# 1       2025-03-17 21:13:00
# 2       2025-06-03 12:42:00
# 3       2024-08-10 15:13:00
# 4       2024-08-19 08:24:00
#                ...
# 1423    2024-06-08 20:42:00
# 1424    2025-11-06 08:17:00
# 1425    2025-03-07 09:07:00
# 1426    2025-04-19 21:52:00
# 1427    2024-09-22 16:36:00
# Name: siparis_tarihi, Length: 1428, dtype: object>
# sehir: <bound method IndexOpsMixin.nunique of 0        İstanbul
# 1       Gaziantep
# 2         Kayseri
# 3         Antalya
# 4       Gaziantep
#           ...
# 1423     İstanbul
# 1424    Gaziantep
# 1425          NaN
# 1426      Kocaeli
# 1427       Ankara
# Name: sehir, Length: 1428, dtype: object>
# bolge: <bound method IndexOpsMixin.nunique of 0                 Marmara
# 1       Güneydoğu Anadolu
# 2              İç Anadolu
# 3                 Akdeniz
# 4       Güneydoğu Anadolu
#               ...
# 1423              Marmara
# 1424    Güneydoğu Anadolu
# 1425              Marmara
# 1426              Marmara
# 1427           İç Anadolu
# Name: bolge, Length: 1428, dtype: object>
# kategori: <bound method IndexOpsMixin.nunique of 0         Kozmetik
# 1             Spor
# 2            Kitap
# 3            Kitap
# 4       Elektronik
#            ...
# 1423          Spor
# 1424          Spor
# 1425    Elektronik
# 1426         Kitap
# 1427      Kozmetik
# Name: kategori, Length: 1428, dtype: object>
# urun_adi: <bound method IndexOpsMixin.nunique of 0               Nemlendirici
# 1                Dambıl Seti
# 2       İş Analitiği Rehberi
# 3               Girişimcilik
# 4                  Powerbank
#                 ...
# 1423               Yoga Matı
# 1424                   Suluk
# 1425                  Webcam
# 1426         Veri Bilimi 101
# 1427             Güneş Kremi
# Name: urun_adi, Length: 1428, dtype: object>
# adet: <bound method IndexOpsMixin.nunique of 0       1
# 1       2
# 2       1
# 3       5
# 4       3
#        ..
# 1423    1
# 1424    2
# 1425    4
# 1426    2
# 1427    1
# Name: adet, Length: 1428, dtype: int64>
# birim_fiyat: <bound method IndexOpsMixin.nunique of 0        414.51
# 1       1475.15
# 2        289.02
# 3        194.78
# 4        841.80
#          ...
# 1423     772.23
# 1424     187.03
# 1425     894.47
# 1426     248.55
# 1427     424.84
# Name: birim_fiyat, Length: 1428, dtype: float64>
# indirim_orani: <bound method IndexOpsMixin.nunique of 0       0.05
# 1       0.10
# 2       0.05
# 3       0.00
# 4       0.05
#         ...
# 1423    0.00
# 1424    0.00
# 1425    0.10
# 1426    0.05
# 1427    0.20
# Name: indirim_orani, Length: 1428, dtype: float64>
# kargo_ucreti: <bound method IndexOpsMixin.nunique of 0       49.9
# 1       29.9
# 2       29.9
# 3       49.9
# 4       39.9
#         ...
# 1423    29.9
# 1424    59.9
# 1425    49.9
# 1426    59.9
# 1427     0.0
# Name: kargo_ucreti, Length: 1428, dtype: float64>
# odeme_turu: <bound method IndexOpsMixin.nunique of 0          Kredi Kartı
# 1          Banka Kartı
# 2          Kredi Kartı
# 3         Kapıda Ödeme
# 4       Dijital Cüzdan
#              ...
# 1423       Kredi Kartı
# 1424       Kredi Kartı
# 1425       Kredi Kartı
# 1426       banka karti
# 1427    Dijital Cüzdan
# Name: odeme_turu, Length: 1428, dtype: object>
# musteri_tipi: <bound method IndexOpsMixin.nunique of 0         Yeni
# 1          VIP
# 2       Mevcut
# 3         Yeni
# 4       Mevcut
#          ...
# 1423    Mevcut
# 1424      Yeni
# 1425    Mevcut
# 1426      Yeni
# 1427      Yeni
# Name: musteri_tipi, Length: 1428, dtype: object>
# teslimat_gunu: <bound method IndexOpsMixin.nunique of 0       3.0
# 1       4.0
# 2       6.0
# 3       3.0
# 4       4.0
#        ...
# 1423    3.0
# 1424    2.0
# 1425    3.0
# 1426    4.0
# 1427    2.0
# Name: teslimat_gunu, Length: 1428, dtype: float64>
# musteri_puani: <bound method IndexOpsMixin.nunique of 0       5.0
# 1       1.0
# 2       2.0
# 3       5.0
# 4       5.0
#        ...
# 1423    2.0
# 1424    4.0
# 1425    5.0
# 1426    3.0
# 1427    4.0
# Name: musteri_puani, Length: 1428, dtype: float64>
# iade_durumu: <bound method IndexOpsMixin.nunique of 0       Hayır
# 1       Hayır
# 2       Hayır
# 3       Hayır
# 4       Hayır
#         ...
# 1423    Hayır
# 1424     Evet
# 1425    Hayır
# 1426    Hayır
# 1427    Hayır
# Name: iade_durumu, Length: 1428, dtype: object>
# kar_marji_orani: <bound method IndexOpsMixin.nunique of 0       0.220
# 1       0.361
# 2       0.348
# 3       0.250
# 4       0.280
#         ...
# 1423    0.275
# 1424    0.243
# 1425    0.355
# 1426    0.373
# 1427    0.317
# Name: kar_marji_orani, Length: 1428, dtype: float64>
# toplam_tutar: <bound method IndexOpsMixin.nunique of 0        443.68
# 1       2685.17
# 2        304.47
# 3       1023.80
# 4       2439.03
#          ...
# 1423     802.13
# 1424     433.96
# 1425    3269.99
# 1426     532.14
# 1427     339.87
# Name: toplam_tutar, Length: 1428, dtype: float64>

# %% [markdown]
# # Kayıp Veri (Missing Value)
#
# Amaç:
#
#     1. Eksik veri tespiti ve farklı eksik veri çözüm yöntemlerini uygulamak
#     2. Eğitimde kullanılacak güncel veri setini kaydetme
#
# Adımlar:
#
#     1. Veri setini yükleme
#     2. Eksik verileri tespit etme
#     3. Eksik veri oranlarını hesaplama
#     4. Eksik veri içeren satırları incele
#     5. Eksik verileri silmek
#     6. Sayısal eksik verileri ortalama ile doldur
#     7. Sayısal eksik verileri medyan ile doldur
#     8. Sayısal eksik verileri mod ile doldur
#     9. Kategorik eksik verileri mod ile doldur
#     10. Kategorik eksik verileri sabit bir değer ile doldurmak
#     11. Eğitimde kullanılacak olan güncel veri setini oluştur
#     12. Düzenlenmiş veri setini kaydet

# %%
import pandas as pd

# %%
# 1. veri setini yükle
df = pd.read_csv("e_ticaret_veri_seti.csv")

# %%
# 2. eksik verileri tespit etme
df.isnull().sum()
# Out:
# siparis_id          0
# musteri_id          0
# siparis_tarihi      0
# sehir              25
# bolge               0
# kategori            0
# urun_adi            0
# adet                0
# birim_fiyat         0
# indirim_orani      16
# kargo_ucreti        0
# odeme_turu         35
# musteri_tipi       42
# teslimat_gunu      28
# musteri_puani      56
# iade_durumu         0
# kar_marji_orani     0
# toplam_tutar        0
# dtype: int64

# %%
#eksik veri oranlarını hesapla
eksik_sayilari = df.isnull().sum()
eksik_oranlari = (eksik_sayilari / len(df)) * 100
eksik_oranlari
# Out:
# siparis_id         0.000000
# musteri_id         0.000000
# siparis_tarihi     0.000000
# sehir              1.750700
# bolge              0.000000
# kategori           0.000000
# urun_adi           0.000000
# adet               0.000000
# birim_fiyat        0.000000
# indirim_orani      1.120448
# kargo_ucreti       0.000000
# odeme_turu         2.450980
# musteri_tipi       2.941176
# teslimat_gunu      1.960784
# musteri_puani      3.921569
# iade_durumu        0.000000
# kar_marji_orani    0.000000
# toplam_tutar       0.000000
# dtype: float64

# %%
# 4. eksik veri olan satırları inceleme
eksik_veri_olan_satirlar = df[df.isnull().any(axis = 1)]
eksik_veri_olan_satirlar.head(10)
# Out:
#    siparis_id musteri_id       siparis_tarihi     sehir       bolge  \
# 19  SIP100677    MUS1148  2024-07-11 16:24:00     Adana     Akdeniz
# 33  SIP101126    MUS1406  2024-09-11 20:05:00    Mersin     Akdeniz
# 50  SIP101040    MUS1386  2025-04-01 09:30:00   Trabzon   Karadeniz
# 60  SIP100890    MUS1271  2024-11-07 19:47:00     İzmir         Ege
# 61  SIP101317    MUS1060  2024-09-05 20:49:00       NaN     Akdeniz
# 70  SIP100715    MUS1033  2024-11-10 21:50:00  İstanbul     Marmara
# 82  SIP100807    MUS1431  2025-01-07 14:12:00    Ankara  İç Anadolu
# 84  SIP100679    MUS1310  2024-05-20 18:51:00     İzmir         Ege
# 86  SIP101071    MUS1131  2024-09-18 12:24:00       NaN  İç Anadolu
# 92  SIP101366    MUS1347  2025-03-04 14:00:00     Bursa     Marmara
#
#        kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 19         Spor         Dambıl Seti     4      1517.65            0.0
# 33   Elektronik  Bluetooth Hoparlör     1      1159.89            0.1
# 50         Spor         Dambıl Seti     1      1554.15            0.0
# 60        Kitap        Girişimcilik     4       216.38            NaN
# 61  Ev ve Yaşam      Saklama Kutusu     1       233.63            0.1
# 70  Ev ve Yaşam              Termos     1       552.05            0.0
# 82     Kozmetik         Güneş Kremi     1       451.28            0.0
# 84  Ev ve Yaşam              Termos     2       477.62            0.0
# 86   Elektronik           Powerbank     1       816.74            0.0
# 92  Ev ve Yaşam           Organizer     1       272.40            0.0
#
#     kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 19          29.9    Kapıda Ödeme       Mevcut            3.0            NaN
# 33          39.9     Kredi Kartı          NaN            2.0            4.0
# 50          49.9     Banka Kartı          NaN            4.0            5.0
# 60          49.9     Kredi Kartı         Yeni            1.0            3.0
# 61          29.9  Dijital Cüzdan         Yeni            5.0            2.0
# 70          39.9             NaN       Mevcut            2.0            3.0
# 82          49.9     Kredi Kartı          NaN            4.0            5.0
# 84          49.9     Kredi Kartı       Mevcut            NaN            4.0
# 86          39.9     Banka Kartı         Yeni            3.0            5.0
# 92          29.9     Kredi Kartı       Mevcut            1.0            NaN
#
#    iade_durumu  kar_marji_orani  toplam_tutar
# 19       Hayır            0.311       6100.50
# 33       Hayır            0.204       1083.80
# 50       Hayır            0.217       1604.05
# 60       Hayır            0.199        915.42
# 61       Hayır            0.385        240.17
# 70       Hayır            0.185        591.95
# 82       Hayır            0.315        501.18
# 84       Hayır            0.323       1005.14
# 86       Hayır            0.301        856.64
# 92       Hayır            0.212        302.30

# %%
# 5. eksik verileri silme
df_silinen = df.dropna() # eksik veri içeren satırları veri setinden çıkardık
df_silinen.shape
# Out:
# (1239, 18)

# %%
# sayısal verileri ortalama ile doldurma
df_ortalama = df.copy()
sayisal_sutunlar = df_ortalama.select_dtypes(include = ["int64", "float64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
for sutun in sayisal_sutunlar:
  df_ortalama[sutun] = df_ortalama[sutun].fillna(df_ortalama[sutun].mean())

# %%
df_ortalama[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
# sayisal eksik verileri medyan ile doldurma
df_medyan = df.copy()
for sutun in sayisal_sutunlar:
  df_medyan[sutun] = df_medyan[sutun].fillna(df_medyan[sutun].median())

df_medyan[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
# sayısal eksik verileri mod ile doldurma

df_mod = df.copy()
for sutun in sayisal_sutunlar:
  mod_degeri = df_mod[sutun].mode()[0]
  df_mod[sutun] = df_mod[sutun].fillna(mod_degeri)
df_mod[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
# 9. kategorik verileri mod ile doldurma
df_mod_kategorik = df.copy()
kategorik_sutunlar = df_mod_kategorik.select_dtypes(include = ["object"]).columns
kategorik_sutunlar
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'odeme_turu', 'musteri_tipi', 'iade_durumu'],
#       dtype='object')

# %%
for sutun in kategorik_sutunlar:
  mod_degeri = df_mod_kategorik[sutun].mode()[0]
  df_mod_kategorik[sutun] = df_mod_kategorik[sutun].fillna(mod_degeri)
df_mod_kategorik[kategorik_sutunlar].isnull().sum()
# Out:
# siparis_id        0
# musteri_id        0
# siparis_tarihi    0
# sehir             0
# bolge             0
# kategori          0
# urun_adi          0
# odeme_turu        0
# musteri_tipi      0
# iade_durumu       0
# dtype: int64

# %%
#10 kategorik eksik verileri sabit değer ile doldurma
df_sabit_kategorik = df.copy()

for sutun in kategorik_sutunlar:
  df_sabit_kategorik[sutun] = df_sabit_kategorik[sutun].fillna("bilinmiyor")

df_sabit_kategorik[kategorik_sutunlar].isnull().sum()
# Out:
# siparis_id        0
# musteri_id        0
# siparis_tarihi    0
# sehir             0
# bolge             0
# kategori          0
# urun_adi          0
# odeme_turu        0
# musteri_tipi      0
# iade_durumu       0
# dtype: int64

# %%
# 11 eğitimde kullanılacak güncel veri seti
# sayısal eksik verileri medyan ile dolduracağız
#kategorik eksik veriler mod ile doldur

# %%
df_guncel = df.copy()

# %%
for sutun in sayisal_sutunlar:
  df_guncel[sutun] = df_guncel[sutun].fillna(df_guncel[sutun].median())

# %%
for sutun in kategorik_sutunlar:
  mod_degeri = df_guncel[sutun].mode()[0]
  df_guncel[sutun] = df_guncel[sutun].fillna(mod_degeri)

# %%
df_guncel.isnull().sum()
# Out:
# siparis_id         0
# musteri_id         0
# siparis_tarihi     0
# sehir              0
# bolge              0
# kategori           0
# urun_adi           0
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# odeme_turu         0
# musteri_tipi       0
# teslimat_gunu      0
# musteri_puani      0
# iade_durumu        0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
df.to_csv("e_ticaret_veri_seti_kayip_veri.csv")

# %% [markdown]
# # Veri Tipleri Dönüşümler
#
# Amaç:
#
#     1. veri setindeki sütunların veri tiplerini incelemek ve gerekli dönüşümleri uygulamak
#     2. güncel veri setini oluşturarak kaydetmek
#
# Adımlar:
#
#     1. Veri setini yüklemek
#     2. veri tiplerini incele
#     3. sayısal , kategorik ve tarih sütunlarını belirlemek
#     4. sipariş tarihini sütununu datetime tipini çevirmek
#     5. Tarih sütununda yeni özellikler üretmek
#     6. kategorik sütunları kategori tipine dönüştürmek
#     7. dönüşüm sonrası veri tipi kontrolü
#     8. güncellenmiş veri setine kaydetme

# %%
import pandas as pd

# %%
# 1. veri setini yükle
df = pd.read_csv("e_ticaret_veri_seti_kayip_veri.csv")

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
#sayisal sütunlar
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar']

# %%
kategorik_sutunlar = df.select_dtypes(include = ["object"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu']

# %%
#4. sipariş tarihini sütununu datetime tipini çevirmek (string > datetime)
df["siparis_tarihi"] = pd.to_datetime(df["siparis_tarihi"])
df["siparis_tarihi"].dtypes
df.dtypes
# Out:
# Unnamed: 0                  int64
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                      object
# bolge                      object
# kategori                   object
# urun_adi                   object
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu                 object
# musteri_tipi               object
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# dtype: object

# %%
#5. Tarih sütununda yeni özellikler üretmek
# yıl ay gün gibi bölmelere ayiriyoruz

df["siparis_yili"] = df["siparis_tarihi"].dt.year
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df["siparis_gunu"] = df["siparis_tarihi"].dt.day
df["hafta gunu"] = df["siparis_tarihi"].dt.day_name()
df.head(5)
# Out:
#    Unnamed: 0 siparis_id musteri_id      siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul
# 1           1  SIP100837    MUS1347 2025-03-17 21:13:00  Gaziantep
# 2           2  SIP100050    MUS1066 2025-06-03 12:42:00    Kayseri
# 3           3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya
# 4           4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep
#
#                bolge    kategori              urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik          Nemlendirici     1       414.51
# 1  Güneydoğu Anadolu        Spor           Dambıl Seti     2      1475.15
# 2         İç Anadolu       Kitap  İş Analitiği Rehberi     1       289.02
# 3            Akdeniz       Kitap          Girişimcilik     5       194.78
# 4  Güneydoğu Anadolu  Elektronik             Powerbank     3       841.80
#
#    ...  musteri_tipi  teslimat_gunu musteri_puani iade_durumu  \
# 0  ...          Yeni            3.0           5.0       Hayır
# 1  ...           VIP            4.0           1.0       Hayır
# 2  ...        Mevcut            6.0           2.0       Hayır
# 3  ...          Yeni            3.0           5.0       Hayır
# 4  ...        Mevcut            4.0           5.0       Hayır
#
#    kar_marji_orani  toplam_tutar siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68         2024            1            13
# 1            0.361       2685.17         2025            3            17
# 2            0.348        304.47         2025            6             3
# 3            0.250       1023.80         2024            8            10
# 4            0.280       2439.03         2024            8            19
#
#    hafta gunu
# 0    Saturday
# 1      Monday
# 2     Tuesday
# 3    Saturday
# 4      Monday
#
# [5 rows x 23 columns]

# %%
#6. kategorik sütunları category tipine dönüştürmek
kategorik_donusum_sutunlari = [
    "sehir",
    "kategori",
    "urun_adi",
    "odeme_turu",
    "musteri_tipi",
    "hafta gunu"
]

# %%
for sutun in kategorik_donusum_sutunlari:
  df[sutun] = df[sutun].astype("category")

#donusum sonrasi kontrol etme
df.dtypes
# Out:
# Unnamed: 0                  int64
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                    category
# bolge                      object
# kategori                 category
# urun_adi                 category
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu               category
# musteri_tipi             category
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# siparis_yili                int32
# siparis_ayi                 int32
# siparis_gunu                int32
# hafta gunu               category
# dtype: object

# %%
#güncellenmis veri setini kayıt etme

df.to_csv("e_ticaret_veri_seti_veri_tipleri.csv")

# %% [markdown]
# # Tekrarlayan Tutarsız Kayıtlar
#
# Amac :
#   1. Veri setindeki tekrarlayan ve tutarsız kayıları tespit edp temizlemek
#   2. güncel veri setini kaydetmek
#
# Adımlar:
#   1. Veri setini yüklemek
#   2. tekrarlayan kayıtları tespit etmek
#   3. tekrarlayan kayıtları incelemek
#   4. tekrarlayan kayıtları temizlemek
#   5. Tutarsız kategorik değerleri incelemek
#   6. şehir sütunundaki tutarsız değerleri düzenlemek
#   7. kategori sütunundaki tutarsız verileri düzenlemek
#   8. Ödeme türü sütunundaki tutarsız verileri düzenlemek
#   9. Müşteri tipi sütunundaki tutarsız değerleri düzenlemek
#   10. Mantıksal olarak hatalı kayıtları temizleme
#   11. Temizlenmiş veri setini kaydet

# %%
import pandas as pd

# %%
#1. veri setini yükleme
df = pd.read_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")

# %%
#2. Tekrarlayan kayıtlar tespit
tekrarlayan_kayitlar = df[df.duplicated()]
tekrarlayan_kayitlar
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 174   SIP100479    MUS1099  2025-06-10 20:32:00   İstanbul            Marmara
# 315   SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 324   SIP100533    MUS1128  2024-11-19 14:22:00    Trabzon          Karadeniz
# 613   SIP100725    MUS1146  2025-05-24 10:10:00    Kocaeli            Marmara
# 637   SIP100940    MUS1032  2025-03-25 20:06:00     Samsun          Karadeniz
# 650   SIP100985    MUS1436  2025-12-18 21:45:00      Konya         İç Anadolu
# 727   SIP100052    MUS1346  2025-03-16 20:37:00   İstanbul            Marmara
# 733   SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 769   SIP100779    MUS1354  2025-12-05 11:19:00   İstanbul            Marmara
# 808   SIP100234    MUS1204  2025-03-03 22:53:00  Gaziantep  Güneydoğu Anadolu
# 830   SIP101042    MUS1325  2025-11-12 15:57:00    Kocaeli            Marmara
# 862   SIP100209    MUS1177  2025-09-13 10:20:00      Bursa            Marmara
# 959   SIP100625    MUS1392  2025-06-15 16:25:00      İzmir                Ege
# 1020  SIP100255    MUS1072  2025-02-15 15:14:00   İstanbul            Marmara
# 1034  SIP100045    MUS1329  2025-02-12 13:17:00   İstanbul            Marmara
# 1075  SIP100116    MUS1152  2024-04-19 11:24:00     Ankara         İç Anadolu
# 1129  SIP100381    MUS1328  2024-02-03 10:38:00     Samsun          Karadeniz
# 1212  SIP100681    MUS1280  2025-05-25 21:46:00      İzmir                Ege
# 1239  SIP100368    MUS1323  2025-01-27 10:26:00      Bursa            Marmara
# 1253  SIP100666    MUS1055  2025-09-10 17:08:00    Kayseri         İç Anadolu
# 1274  SIP100901    MUS1067  2025-03-02 21:10:00      İzmir                Ege
# 1307  SIP100079    MUS1360  2025-07-20 16:22:00      Adana            Akdeniz
# 1355  SIP100030    MUS1305  2025-06-27 10:03:00   İstanbul            Marmara
# 1372  SIP100627    MUS1370  2025-12-07 16:57:00      İzmir                Ege
# 1385  SIP100221    MUS1296  2025-09-03 15:16:00    Kayseri         İç Anadolu
# 1390  SIP100868    MUS1276  2025-10-26 10:41:00    Kayseri         İç Anadolu
# 1392  SIP100240    MUS1032  2025-08-19 19:36:00  Gaziantep  Güneydoğu Anadolu
# 1421  SIP100480    MUS1323  2024-06-20 20:34:00     Ankara         İç Anadolu
#
#          kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 174      Kozmetik           Güneş Kremi     3       455.19           0.00
# 315    Elektronik             Powerbank     3       841.80           0.05
# 324         Kitap        Python Notları     2       225.82           0.00
# 613         Kitap        Zaman Yönetimi     2       154.18           0.05
# 637      Kozmetik                 Serum     1       507.46           0.15
# 650          Spor                 Suluk     2       203.15           0.15
# 727          Ofis        Mekanik Klavye     3      2052.67           0.10
# 733         Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 769         Kitap        Python Notları     4       219.14           0.00
# 808    Elektronik    Bluetooth Hoparlör     1      1220.47           0.05
# 830   Ev ve Yaşam        Saklama Kutusu     1       242.95           0.20
# 862   Ev ve Yaşam        Saklama Kutusu     1       236.34           0.00
# 959    Elektronik    Bluetooth Hoparlör     1      1312.49           0.15
# 1020        kitap       Veri Bilimi 101     1       244.09           0.05
# 1034   Elektronik    Bluetooth Hoparlör     3      1196.85           0.00
# 1075         Spor          Direnç Bandı     1       235.20           0.05
# 1129         Spor          Spor Çantası     2       982.46           0.10
# 1212   Elektronik             Powerbank     1       749.85           0.00
# 1239   Elektronik                Webcam     1       938.08           0.00
# 1253         Ofis             Mouse Pad     1       164.18           0.05
# 1274         Spor          Direnç Bandı     4       243.83           0.00
# 1307         Ofis            Not Tutucu     1       123.30           0.15
# 1355         Spor          Spor Çantası     3       890.81           0.15
# 1372     Kozmetik    Yüz Temizleme Jeli     3       324.24           0.00
# 1385        Kitap       Veri Bilimi 101     1       272.69           0.15
# 1390  Ev ve Yaşam          Kahve Kupası     1       186.51           0.00
# 1392         Ofis             Mouse Pad     2       154.56           0.15
# 1421   Elektronik     Kablosuz Kulaklık     1      1468.25           0.05
#
#       ...  musteri_tipi teslimat_gunu musteri_puani  iade_durumu  \
# 174   ...          Yeni           1.0           5.0        Hayır
# 315   ...        Mevcut           4.0           5.0        Hayır
# 324   ...          Yeni           4.0           5.0        Hayır
# 613   ...          Yeni           3.0           5.0        Hayır
# 637   ...        Mevcut           3.0           4.0         Evet
# 650   ...        Mevcut           4.0           4.0        Hayır
# 727   ...          Yeni           3.0           4.0        Hayır
# 733   ...        Mevcut           6.0           2.0        Hayır
# 769   ...          Yeni          18.0           5.0         Evet
# 808   ...           VIP           2.0           3.0        Hayır
# 830   ...        Mevcut           5.0           1.0        Hayır
# 862   ...          Yeni           2.0           4.0        Hayır
# 959   ...          Yeni           4.0           2.0        Hayır
# 1020  ...        Mevcut           2.0           5.0        Hayır
# 1034  ...           VIP           1.0           5.0        Hayır
# 1075  ...        Mevcut           4.0           4.0        Hayır
# 1129  ...        Mevcut           2.0           3.0        Hayır
# 1212  ...        Mevcut           2.0           3.0        Hayır
# 1239  ...           VIP           2.0           5.0        Hayır
# 1253  ...        Mevcut           1.0           5.0        Hayır
# 1274  ...          Yeni           5.0           4.0        Hayır
# 1307  ...        Mevcut           1.0           5.0        Hayır
# 1355  ...          Yeni           4.0           3.0        Hayır
# 1372  ...        Mevcut           2.0           5.0        Hayır
# 1385  ...        Mevcut           5.0           4.0        Hayır
# 1390  ...        Mevcut           6.0           5.0        Hayır
# 1392  ...        Mevcut           6.0           4.0        Hayır
# 1421  ...        Mevcut           2.0           4.0        Hayır
#
#       kar_marji_orani toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 174             0.200      1415.47          2025            6            10
# 315             0.280      2439.03          2024            8            19
# 324             0.234       491.54          2024           11            19
# 613             0.385       342.84          2025            5            24
# 637             0.402       471.24          2025            3            25
# 650             0.277       395.26          2025           12            18
# 727             0.398      5592.11          2025            3            16
# 733             0.348       304.47          2025            6             3
# 769             0.408       906.46          2025           12             5
# 808             0.267      1209.35          2025            3             3
# 830             0.219       224.26          2025           11            12
# 862             0.289       276.24          2025            9            13
# 959             0.273      1155.52          2025            6            15
# 1020            0.377       281.79          2025            2            15
# 1034            0.262      3640.45          2025            2            12
# 1075            0.365       273.34          2024            4            19
# 1129            0.304      1798.33          2024            2             3
# 1212            0.375       799.75          2025            5            25
# 1239            0.326       987.98          2025            1            27
# 1253            0.371       185.87          2025            9            10
# 1274            0.376      1035.22          2025            3             2
# 1307            0.207       134.70          2025            7            20
# 1355            0.314      2311.47          2025            6            27
# 1372            0.275       972.72          2025           12             7
# 1385            0.382       291.69          2025            9             3
# 1390            0.407       236.41          2025           10            26
# 1392            0.279       292.65          2025            8            19
# 1421            0.275      1434.74          2024            6            20
#
#       haftanin_gunu
# 174         Tuesday
# 315          Monday
# 324         Tuesday
# 613        Saturday
# 637         Tuesday
# 650        Thursday
# 727          Sunday
# 733         Tuesday
# 769          Friday
# 808          Monday
# 830       Wednesday
# 862        Saturday
# 959          Sunday
# 1020       Saturday
# 1034      Wednesday
# 1075         Friday
# 1129       Saturday
# 1212         Sunday
# 1239         Monday
# 1253      Wednesday
# 1274         Sunday
# 1307         Sunday
# 1355         Friday
# 1372         Sunday
# 1385      Wednesday
# 1390         Sunday
# 1392        Tuesday
# 1421       Thursday
#
# [28 rows x 22 columns]

# %%
#3. tekrarlayan kayıtlar incele
tekrarlayan_kayitlar.head(10)
# Out:
#     siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 174  SIP100479    MUS1099  2025-06-10 20:32:00   İstanbul            Marmara
# 315  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 324  SIP100533    MUS1128  2024-11-19 14:22:00    Trabzon          Karadeniz
# 613  SIP100725    MUS1146  2025-05-24 10:10:00    Kocaeli            Marmara
# 637  SIP100940    MUS1032  2025-03-25 20:06:00     Samsun          Karadeniz
# 650  SIP100985    MUS1436  2025-12-18 21:45:00      Konya         İç Anadolu
# 727  SIP100052    MUS1346  2025-03-16 20:37:00   İstanbul            Marmara
# 733  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 769  SIP100779    MUS1354  2025-12-05 11:19:00   İstanbul            Marmara
# 808  SIP100234    MUS1204  2025-03-03 22:53:00  Gaziantep  Güneydoğu Anadolu
#
#        kategori              urun_adi  adet  birim_fiyat  indirim_orani  ...  \
# 174    Kozmetik           Güneş Kremi     3       455.19           0.00  ...
# 315  Elektronik             Powerbank     3       841.80           0.05  ...
# 324       Kitap        Python Notları     2       225.82           0.00  ...
# 613       Kitap        Zaman Yönetimi     2       154.18           0.05  ...
# 637    Kozmetik                 Serum     1       507.46           0.15  ...
# 650        Spor                 Suluk     2       203.15           0.15  ...
# 727        Ofis        Mekanik Klavye     3      2052.67           0.10  ...
# 733       Kitap  İş Analitiği Rehberi     1       289.02           0.05  ...
# 769       Kitap        Python Notları     4       219.14           0.00  ...
# 808  Elektronik    Bluetooth Hoparlör     1      1220.47           0.05  ...
#
#      musteri_tipi teslimat_gunu musteri_puani  iade_durumu  kar_marji_orani  \
# 174          Yeni           1.0           5.0        Hayır            0.200
# 315        Mevcut           4.0           5.0        Hayır            0.280
# 324          Yeni           4.0           5.0        Hayır            0.234
# 613          Yeni           3.0           5.0        Hayır            0.385
# 637        Mevcut           3.0           4.0         Evet            0.402
# 650        Mevcut           4.0           4.0        Hayır            0.277
# 727          Yeni           3.0           4.0        Hayır            0.398
# 733        Mevcut           6.0           2.0        Hayır            0.348
# 769          Yeni          18.0           5.0         Evet            0.408
# 808           VIP           2.0           3.0        Hayır            0.267
#
#     toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  haftanin_gunu
# 174      1415.47          2025            6            10        Tuesday
# 315      2439.03          2024            8            19         Monday
# 324       491.54          2024           11            19        Tuesday
# 613       342.84          2025            5            24       Saturday
# 637       471.24          2025            3            25        Tuesday
# 650       395.26          2025           12            18       Thursday
# 727      5592.11          2025            3            16         Sunday
# 733       304.47          2025            6             3        Tuesday
# 769       906.46          2025           12             5         Friday
# 808      1209.35          2025            3             3         Monday
#
# [10 rows x 22 columns]

# %%
#4. tekrarlayan kayıtları temizleme
df = df.drop_duplicates()
df.shape
# Out:
# (1400, 22)

# %%
#5. tutarsız değerlerin incelenmesi
df["sehir"].unique()
#istanbul , Ankara , Gaziantep , İzmir problemli
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'İzmir',
#        'Eskişehir', 'Samsun', 'istanbul', 'ankara', 'Istanbul',
#        'gaziantep', 'Izmir'], dtype=object)

# %%
df["kategori"].unique()
#spor , ofis , kitap , ev yaşam , kozmetik , Elektronik problemli
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'ofis',
#        'Ev ve Yaşam', 'Elektronik ', 'spor', 'kozmetık', 'ev ve yaşam',
#        'kitap', 'Kozmetik ', 'elektronik', 'Ev&Yaşam'], dtype=object)

# %%
df["musteri_tipi"].unique()
#yeni , vip , mevcut problemli
# Out:
# array(['Yeni', 'VIP', 'Mevcut', 'yeni', 'Vip', 'mevcut', 'vip'],
#       dtype=object)

# %%
# Yardımcı fonksiyon , metinleri normalize etme
#büyük küçük harf , boşlukların kaldırılması , Türkçe karakter kaynaklı farkların düzenlenmesi
def metin_normalize(series):

  return(
      series.astype(str)
      .str.strip()
      .str.lower()
      .str.replace("i̇", "i", regex=False)
      .str.replace("ı", "i", regex=False)
      .str.replace("ö", "o", regex=False)
      .str.replace("ü", "u", regex=False)
      .str.replace("ç", "c", regex=False)
      .str.replace("ş", "s", regex=False)
      .str.replace("ğ", "g", regex=False)
  )

# %%
# 6.şehir sütunundaki tutarsız değerleri güncelleme
df["sehir"] = metin_normalize(df["sehir"])
df["sehir"].unique()
# Out:
# array(['istanbul', 'gaziantep', 'kayseri', 'antalya', 'konya', 'ankara',
#        'bursa', 'trabzon', 'adana', 'mersin', 'kocaeli', 'izmir',
#        'eskisehir', 'samsun'], dtype=object)

# %%
sehir_duzeltme_haritasi = {
    "istanbul": "İstanbul",
    "ankara": "Ankara",
    "izmir": "İzmir",
    "antalya": "Antalya",
    "konya": "Konya",
    "bursa": "Bursa",
    "adana": "Adana",
    "gaziantep": "Gaziantep",
    "mersin": "Mersin",
    "kayseri": "Kayseri",
    "eskisehir": "Eskişehir",
    "samsun": "Samsun",
    "trabzon": "Trabzon",
    "kocaeli": "Kocaeli"
}
df["sehir"] = df["sehir"].replace(sehir_duzeltme_haritasi)
df["sehir"].unique()
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'İzmir',
#        'Eskişehir', 'Samsun'], dtype=object)

# %%
#7 . kategori sütunu normalize
df["kategori"] = metin_normalize(df["kategori"])
df["kategori"].unique()
# Out:
# array(['kozmetik', 'spor', 'kitap', 'elektronik', 'ofis', 'ev ve yasam',
#        'ev&yasam'], dtype=object)

# %%
kategori_duzeltme_haritası = {
    "ev&yasam" : "ev ve yasam"
}
df["kategori"] = df["kategori"].replace(kategori_duzeltme_haritası)
df["kategori"].unique()
# Out:
# array(['kozmetik', 'spor', 'kitap', 'elektronik', 'ofis', 'ev ve yasam'],
#       dtype=object)

# %%
#8 ödeme türü
df["odeme_turu"] = metin_normalize(df["odeme_turu"])
df["odeme_turu"].unique()
# Out:
# array(['kredi karti', 'banka karti', 'kapida odeme', 'dijital cuzdan',
#        'havale/eft', 'kart', 'eft', 'havale'], dtype=object)

# %%
odeme_turu_duzeltme_haritasi = {
    "kredi karti": "Kredi Kartı",
    "kart": "Kredi Kartı",
    "banka karti": "Banka Kartı",
    "dijital cuzdan": "Dijital Cüzdan",
    "kapida odeme": "Kapıda Ödeme",
    "havale": "Havale/EFT",
    "eft": "Havale/EFT",
    "havale/eft": "Havale/EFT"
}
df["odeme_turu"] = df["odeme_turu"].replace(odeme_turu_duzeltme_haritasi)
df["odeme_turu"].unique()
# Out:
# array(['Kredi Kartı', 'Banka Kartı', 'Kapıda Ödeme', 'Dijital Cüzdan',
#        'Havale/EFT'], dtype=object)

# %%
#9. müsteri tipindeki düzeltmeler
df["musteri_tipi"] = metin_normalize(df["musteri_tipi"])
df["musteri_tipi"].unique()
# Out:
# array(['yeni', 'vip', 'mevcut'], dtype=object)

# %%
musteri_tipi_duzeltme_haritasi = {
    "mevcut": "Mevcut",
    "yeni": "Yeni",
    "vip": "VIP"
}
df["musteri_tipi"] = df["musteri_tipi"].replace(musteri_tipi_duzeltme_haritasi)
df["musteri_tipi"].unique()
# Out:
# array(['Yeni', 'VIP', 'Mevcut'], dtype=object)

# %%
df["musteri_tipi"].value_counts()
# Out:
# musteri_tipi
# Mevcut    716
# Yeni      520
# VIP       164
# Name: count, dtype: int64

# %%
#10 mantıksal hatalı kayıtları inceleme
hatali_kayitlar = df[
    (df["siparis_yili"] > 2026) |
    (df["siparis_ayi"] > 12) |
    (df["siparis_gunu"] > 31) |
    (df["adet"] <= 0) |
    (df["toplam_tutar"] <= 0) |
    (df["birim_fiyat"] <= 0) |
    (df["teslimat_gunu"] < 0) |
    (df["musteri_puani"] < 0) |
    (df["musteri_puani"] > 5)

]
len(hatali_kayitlar)
# Out:
# 2

# %%
pd.set_option("display.max_columns", None)
hatali_kayitlar
# Out:
#      siparis_id musteri_id       siparis_tarihi     sehir    bolge  kategori  \
# 609   SIP100095    MUS1165  2025-10-12 21:31:00  İstanbul  Marmara  kozmetik
# 1008  SIP101290    MUS1225  2024-01-16 21:46:00   Kocaeli  Marmara  kozmetik
#
#                 urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 609              Şampuan     2       190.17           0.10           0.0
# 1008  Yüz Temizleme Jeli     2       303.82           0.05          29.9
#
#           odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 609   Dijital Cüzdan       Mevcut            3.0            6.0       Hayır
# 1008     Kredi Kartı         Yeni            5.0            7.0        Evet
#
#       kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 609             0.416        342.31          2025           10            12
# 1008            0.287        607.16          2024            1            16
#
#      haftanin_gunu
# 609         Sunday
# 1008       Tuesday

# %%
#11.Mantıksal hataları temizleyelim
df = df[
    (df["adet"] > 0) &
    (df["toplam_tutar"] > 0) &
    (df["birim_fiyat"] > 0) &
    (df["teslimat_gunu"] >= 0) &
    (df["musteri_puani"] >= 0) &
    (df["musteri_puani"] <= 5)
]
df.shape
# Out:
# (1398, 22)

# %%
df.to_csv("e_ticaret_veri_seti_tekrarlayan_kayitlar_duzenlendi.csv")

# %% [markdown]
# #Aykırı Değerleri İnceleme
#
# Amaç :
#   1. veri setindeki aykırı değerlerin tespit edilmesi
#   2. aykırı değerleri temizleyerek güncel veri setleri oluşturulur
#
# Adımlar :
#   1. Veri setini yükle
#   2. Sayısal sütunları belirle
#   3. sayisal sütunları özet istatistiklerini hesapla
#   4. iqr ile aykırı değer sınırlarını hesapla
#   5. aykırı değer içeren kayıtları tespit etmek
#   6. aykırı değer sayılarını sütun bazında incele
#   7. aykırı değer içeren kayıtları veri setinden temizlemek
#   8. Temzilenmiş veri setini kaydetmek

# %%
import pandas as pd

# %%
df = pd.read_csv("e_ticaret_veri_seti_tekrarlayan_kayitlar_duzenlendi.csv")

# %%
#sayısal sütunlarn belirlenmesi
sayisal_sutunlar = df.select_dtypes(["int64","float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
#sayisal sütunların özet istatistiklerini inceleyelim
df[sayisal_sutunlar].describe()
# Out:
#         Unnamed: 0         adet   birim_fiyat  indirim_orani  kargo_ucreti  \
# count  1398.000000  1398.000000   1398.000000    1398.000000   1398.000000
# mean    708.155937     2.143062    660.712818       0.051717     39.728398
# std     411.970532     2.031849   1051.014558       0.059681     14.188925
# min       0.000000     1.000000     93.110000       0.000000      0.000000
# 25%     352.250000     1.000000    198.855000       0.000000     29.900000
# 50%     705.500000     2.000000    287.120000       0.050000     39.900000
# 75%    1064.750000     3.000000    817.335000       0.100000     49.900000
# max    1427.000000    38.000000  18145.230000       0.200000     59.900000
#
#        teslimat_gunu  musteri_puani  kar_marji_orani  toplam_tutar  \
# count    1398.000000    1398.000000      1398.000000   1398.000000
# mean        3.355508       3.997854         0.302446   1377.934642
# std         1.771142       1.071193         0.069861   2988.042747
# min         1.000000       0.000000         0.180000     89.680000
# 25%         2.000000       4.000000         0.243250    327.190000
# 50%         3.000000       4.000000         0.305000    670.965000
# 75%         4.000000       5.000000         0.362000   1393.250000
# max        31.000000       5.000000         0.420000  63870.200000
#
#        siparis_yili  siparis_ayi  siparis_gunu
# count   1398.000000  1398.000000   1398.000000
# mean    2024.528612     6.394134     15.655222
# std        0.499359     3.455187      8.720828
# min     2024.000000     1.000000      1.000000
# 25%     2024.000000     3.000000      8.000000
# 50%     2025.000000     6.000000     16.000000
# 75%     2025.000000     9.000000     23.000000
# max     2025.000000    12.000000     31.000000

# %%
"""
birim fiyat
IQR = Q3(75%) - Q1(25%)
817 - 198 = 619

üst sınır = Q3(75%) + k * IQR
alt sınır = Q1(%25) + k * IQR (k  değeri genelde 1.5)
k = 1 olsun
    Üst sınır = 817 + 619 = 1436
    Alt sınır = 198 - 619 = -421
  Outlier = üst sınır ve alt sınır dışında kalan örnekler
"""
# Out:
# '\nbirim fiyat\nIQR = Q3(75%) - Q1(25%)\n817 - 198 = 619\n\nüst sınır = Q3(75%) + k * IQR\nalt sınır = Q1(%25) + k * IQR (k  değeri genelde 1.5)\nk = 1 olsun\n    Üst sınır = 817 + 619 = 1436\n    Alt sınır = 198 - 619 = -421\n  Outlier = üst sınır ve alt sınır dışında kalan örnekler\n'

# %%
# 4. IQR ile aykırı değer sınırlarını hesaplama
aykiri_sinirlar =  {}

for sutun in sayisal_sutunlar:

  q1 = df[sutun].quantile(0.25)
  q3 = df[sutun].quantile(0.75)

  iqr = q3 - q1
  alt_sinir = q1 - 1.5 * iqr
  ust_sinir = q3 + 1.5 * iqr

  aykiri_sinirlar[sutun] = {
      "q1" : q1,
      "q3" : q3,
      "iqr" : iqr,
      "alt_sinir" : alt_sinir,
      "ust_sinir" : ust_sinir
  }

aykiri_sinirlar
# Out:
# {'Unnamed: 0': {'q1': np.float64(352.25),
#   'q3': np.float64(1064.75),
#   'iqr': np.float64(712.5),
#   'alt_sinir': np.float64(-716.5),
#   'ust_sinir': np.float64(2133.5)},
#  'adet': {'q1': np.float64(1.0),
#   'q3': np.float64(3.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-2.0),
#   'ust_sinir': np.float64(6.0)},
#  'birim_fiyat': {'q1': np.float64(198.85500000000002),
#   'q3': np.float64(817.335),
#   'iqr': np.float64(618.48),
#   'alt_sinir': np.float64(-728.865),
#   'ust_sinir': np.float64(1745.055)},
#  'indirim_orani': {'q1': np.float64(0.0),
#   'q3': np.float64(0.1),
#   'iqr': np.float64(0.1),
#   'alt_sinir': np.float64(-0.15000000000000002),
#   'ust_sinir': np.float64(0.25)},
#  'kargo_ucreti': {'q1': np.float64(29.9),
#   'q3': np.float64(49.9),
#   'iqr': np.float64(20.0),
#   'alt_sinir': np.float64(-0.10000000000000142),
#   'ust_sinir': np.float64(79.9)},
#  'teslimat_gunu': {'q1': np.float64(2.0),
#   'q3': np.float64(4.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-1.0),
#   'ust_sinir': np.float64(7.0)},
#  'musteri_puani': {'q1': np.float64(4.0),
#   'q3': np.float64(5.0),
#   'iqr': np.float64(1.0),
#   'alt_sinir': np.float64(2.5),
#   'ust_sinir': np.float64(6.5)},
#  'kar_marji_orani': {'q1': np.float64(0.24325),
#   'q3': np.float64(0.362),
#   'iqr': np.float64(0.11875),
#   'alt_sinir': np.float64(0.06512500000000002),
#   'ust_sinir': np.float64(0.540125)},
#  'toplam_tutar': {'q1': np.float64(327.19),
#   'q3': np.float64(1393.25),
#   'iqr': np.float64(1066.06),
#   'alt_sinir': np.float64(-1271.8999999999999),
#   'ust_sinir': np.float64(2992.34)},
#  'siparis_yili': {'q1': np.float64(2024.0),
#   'q3': np.float64(2025.0),
#   'iqr': np.float64(1.0),
#   'alt_sinir': np.float64(2022.5),
#   'ust_sinir': np.float64(2026.5)},
#  'siparis_ayi': {'q1': np.float64(3.0),
#   'q3': np.float64(9.0),
#   'iqr': np.float64(6.0),
#   'alt_sinir': np.float64(-6.0),
#   'ust_sinir': np.float64(18.0)},
#  'siparis_gunu': {'q1': np.float64(8.0),
#   'q3': np.float64(23.0),
#   'iqr': np.float64(15.0),
#   'alt_sinir': np.float64(-14.5),
#   'ust_sinir': np.float64(45.5)}}

# %%
#5. aykırı değer içeren kayıtları tespit et
aykiri_maskesi = pd.Series(False, index = df.index)

for sutun in sayisal_sutunlar:
  alt_sinir = aykiri_sinirlar[sutun]["alt_sinir"]
  ust_sinir = aykiri_sinirlar[sutun]["ust_sinir"]

  sutun_maskesi = aykiri_maskesi | (df[sutun] < alt_sinir) | (df[sutun] > ust_sinir)
  aykiri_maskesi = aykiri_maskesi | sutun_maskesi

# %%
aykiri_kayitlar = df[aykiri_maskesi]
aykiri_kayitlar
# Out:
#       Unnamed: 0 siparis_id musteri_id       siparis_tarihi      sehir  \
# 1              1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep
# 2              2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri
# 6              6  SIP101351    MUS1011  2025-02-27 11:35:00   İstanbul
# 7              7  SIP101172    MUS1357  2024-07-22 13:26:00     Ankara
# 8              8  SIP100779    MUS1354  2025-12-05 11:19:00   İstanbul
# ...          ...        ...        ...                  ...        ...
# 1387        1416  SIP100177    MUS1075  2024-01-29 13:59:00    Trabzon
# 1389        1418  SIP100056    MUS1238  2024-04-19 20:27:00     Ankara
# 1390        1419  SIP101279    MUS1149  2024-08-24 08:38:00     Ankara
# 1393        1423  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul
# 1395        1425  SIP101210    MUS1122  2025-03-07 09:07:00   İstanbul
#
#                   bolge    kategori              urun_adi  adet  birim_fiyat  \
# 1     Güneydoğu Anadolu        spor           Dambıl Seti     2      1475.15
# 2            İç Anadolu       kitap  İş Analitiği Rehberi     1       289.02
# 6               Marmara        ofis             Mouse Pad     3       169.47
# 7            İç Anadolu        ofis        Mekanik Klavye     3      2344.47
# 8               Marmara       kitap        Python Notları     4       219.14
# ...                 ...         ...                   ...   ...          ...
# 1387          Karadeniz        ofis        Mekanik Klavye     3      2169.51
# 1389         İç Anadolu       kitap       Veri Bilimi 101     2       255.70
# 1390         İç Anadolu  elektronik           Akıllı Saat     4      3074.80
# 1393            Marmara        spor             Yoga Matı     1       772.23
# 1395            Marmara  elektronik                Webcam     4       894.47
#
#       indirim_orani  kargo_ucreti   odeme_turu musteri_tipi  teslimat_gunu  \
# 1              0.10          29.9  Banka Kartı          VIP            4.0
# 2              0.05          29.9  Kredi Kartı       Mevcut            6.0
# 6              0.05          29.9   Havale/EFT          VIP            3.0
# 7              0.00          59.9  Kredi Kartı       Mevcut            3.0
# 8              0.00          29.9  Kredi Kartı         Yeni           18.0
# ...             ...           ...          ...          ...            ...
# 1387           0.00          39.9  Kredi Kartı       Mevcut            1.0
# 1389           0.05          59.9  Kredi Kartı       Mevcut            3.0
# 1390           0.15          39.9  Banka Kartı         Yeni            4.0
# 1393           0.00          29.9  Kredi Kartı       Mevcut            3.0
# 1395           0.10          49.9  Kredi Kartı       Mevcut            3.0
#
#       musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 1               1.0       Hayır            0.361       2685.17          2025
# 2               2.0       Hayır            0.348        304.47          2025
# 6               2.0        Evet            0.382        512.89          2025
# 7               4.0       Hayır            0.312       7093.31          2024
# 8               5.0        Evet            0.408        906.46          2025
# ...             ...         ...              ...           ...           ...
# 1387            4.0       Hayır            0.273       6548.43          2024
# 1389            2.0       Hayır            0.247        545.73          2024
# 1390            5.0       Hayır            0.414      10494.22          2024
# 1393            2.0       Hayır            0.275        802.13          2024
# 1395            5.0       Hayır            0.355       3269.99          2025
#
#       siparis_ayi  siparis_gunu haftanin_gunu
# 1               3            17        Monday
# 2               6             3       Tuesday
# 6               2            27      Thursday
# 7               7            22        Monday
# 8              12             5        Friday
# ...           ...           ...           ...
# 1387            1            29        Monday
# 1389            4            19        Friday
# 1390            8            24      Saturday
# 1393            6             8      Saturday
# 1395            3             7        Friday
#
# [303 rows x 23 columns]

# %%
# 6. aykırı değer sayılarını sütun bazında incele
for sutun in sayisal_sutunlar:
  alt_sinir = aykiri_sinirlar[sutun]["alt_sinir"]
  ust_sinir = aykiri_sinirlar[sutun]["ust_sinir"]

  aykiri_sayisi = ((df[sutun] < alt_sinir) | (df[sutun] > ust_sinir)).sum()
  print(f"Sütun aykiri sayisi = {aykiri_sayisi}")
# Out:
# Sütun aykiri sayisi = 0
# Sütun aykiri sayisi = 6
# Sütun aykiri sayisi = 92
# Sütun aykiri sayisi = 0
# Sütun aykiri sayisi = 0
# Sütun aykiri sayisi = 5
# Sütun aykiri sayisi = 151
# Sütun aykiri sayisi = 0
# Sütun aykiri sayisi = 134
# Sütun aykiri sayisi = 0
# Sütun aykiri sayisi = 0
# Sütun aykiri sayisi = 0

# %%
# 7. aykiri değer içeren kayıtları temizleme
df_temiz = df[~aykiri_maskesi].copy()
df_temiz.shape
# Out:
# (1095, 23)

# %%
# 8. temizlenmiş verileri kaydetme
df_temiz.to_csv("e_ticaret_veri_seti_temizlendi.csv")

# %% [markdown]
# # Kategorik Veri Analizi
#
# Amaç :
#   1. Veri setindeki kategorik sütunları incelemek ve dağılımlarını analiz etmek
#   2. Frekans, oran ve görselleştirme yöntemleri ile kategorik verileri yorumlama
#
# Adımlar:
#
#     Veri setini yüklemek
#     Kategorik sütunları belirlemek
#     Kategorik sütunların genel bilgisini incelemek
#     Her kategorik sütun için frekans analizi yapmak
#     Her kategorik sütun için oran analizi yapmak
#     En sık görülen kategorileri incele
#     En az görülen kategorileri incele
#     Belirli sütunlar üzerinde detaylı kategorik analiz
#     Belirli sütunlar için count plot çizdirme

# %%
import pandas as pd
import matplotlib.pyplot as plt # görsel
import seaborn as sns # görsel

# %%
df = pd.read_csv("e_ticaret_veri_seti_temizlendi.csv")

# %%
# kategorik sütunlar
kategorik_sutunlar = df.select_dtypes(include = ["object","category"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu',
#  'haftanin_gunu']

# %%
# 3. kategorik sütunların genel bilgisi
for sutun in kategorik_sutunlar:
  print(f"sutun adı = {sutun}")
  print(f"veri tipi = {df[sutun].dtype}")
  print(f"benzersiz değer sayisi = {df[sutun].nunique()}\n")
# Out:
# sutun adı = siparis_id
# veri tipi = object
# benzersiz değer sayisi = 1095
#
# sutun adı = musteri_id
# veri tipi = object
# benzersiz değer sayisi = 411
#
# sutun adı = siparis_tarihi
# veri tipi = object
# benzersiz değer sayisi = 1094
#
# sutun adı = sehir
# veri tipi = object
# benzersiz değer sayisi = 14
#
# sutun adı = bolge
# veri tipi = object
# benzersiz değer sayisi = 6
#
# sutun adı = kategori
# veri tipi = object
# benzersiz değer sayisi = 6
#
# sutun adı = urun_adi
# veri tipi = object
# benzersiz değer sayisi = 28
#
# sutun adı = odeme_turu
# veri tipi = object
# benzersiz değer sayisi = 5
#
# sutun adı = musteri_tipi
# veri tipi = object
# benzersiz değer sayisi = 3
#
# sutun adı = iade_durumu
# veri tipi = object
# benzersiz değer sayisi = 2
#
# sutun adı = haftanin_gunu
# veri tipi = object
# benzersiz değer sayisi = 7

# %%
# 4. her kategorik sütun için frekans analizi
for sutun in kategorik_sutunlar:
  print(df[sutun].value_counts())
  print(" ")
# Out:
# siparis_id
# SIP100642    1
# SIP101125    1
# SIP100263    1
# SIP100707    1
# SIP100687    1
#             ..
# SIP100161    1
# SIP100320    1
# SIP101066    1
# SIP101295    1
# SIP100308    1
# Name: count, Length: 1095, dtype: int64
#
# musteri_id
# MUS1433    9
# MUS1360    7
# MUS1289    7
# MUS1072    6
# MUS1177    6
#           ..
# MUS1443    1
# MUS1335    1
# MUS1375    1
# MUS1239    1
# MUS1088    1
# Name: count, Length: 411, dtype: int64
#
# siparis_tarihi
# 2025-01-09 13:12:00    2
# 2025-04-30 22:18:00    1
# 2025-05-06 10:33:00    1
# 2025-04-02 08:16:00    1
# 2025-07-08 14:48:00    1
#                       ..
# 2024-12-19 19:50:00    1
# 2024-06-20 20:17:00    1
# 2024-04-14 19:49:00    1
# 2025-04-16 10:53:00    1
# 2025-08-31 15:11:00    1
# Name: count, Length: 1094, dtype: int64
#
# sehir
# İstanbul     264
# Ankara       124
# İzmir        118
# Antalya       86
# Konya         77
# Bursa         67
# Adana         63
# Gaziantep     49
# Mersin        46
# Samsun        45
# Eskişehir     45
# Trabzon       44
# Kayseri       36
# Kocaeli       31
# Name: count, dtype: int64
#
# bolge
# Marmara              350
# İç Anadolu           284
# Akdeniz              195
# Ege                  124
# Karadeniz             92
# Güneydoğu Anadolu     50
# Name: count, dtype: int64
#
# kategori
# kitap          223
# kozmetik       200
# spor           186
# ev ve yasam    184
# ofis           162
# elektronik     140
# Name: count, dtype: int64
#
# urun_adi
# Suluk                   51
# Powerbank               49
# Zaman Yönetimi          47
# Not Tutucu              47
# Python Notları          46
# Veri Bilimi 101         46
# Saklama Kutusu          44
# İş Analitiği Rehberi    43
# Şampuan                 41
# Girişimcilik            41
# Yüz Temizleme Jeli      41
# Nemlendirici            41
# Kalem Seti              40
# Defter Seti             40
# Serum                   40
# Direnç Bandı            39
# Termos                  38
# Güneş Kremi             37
# Yoga Matı               36
# Spor Çantası            35
# Masa Lambası            35
# Mouse Pad               35
# Kahve Kupası            34
# Webcam                  34
# Organizer               33
# Bluetooth Hoparlör      32
# Kablosuz Kulaklık       25
# Dambıl Seti             25
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       583
# Banka Kartı       169
# Dijital Cüzdan    153
# Havale/EFT        111
# Kapıda Ödeme       79
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1007
# Evet       88
# Name: count, dtype: int64
#
# haftanin_gunu
# Saturday     169
# Tuesday      169
# Wednesday    163
# Thursday     157
# Sunday       150
# Monday       144
# Friday       143
# Name: count, dtype: int64

# %%
# her kategorik sütun için oran analizi
for sutun in kategorik_sutunlar:
  print((df[sutun].value_counts(normalize = True) * 100).round(2))
  print(" ")
# Out:
# siparis_id
# SIP100642    0.09
# SIP101125    0.09
# SIP100263    0.09
# SIP100707    0.09
# SIP100687    0.09
#              ...
# SIP100161    0.09
# SIP100320    0.09
# SIP101066    0.09
# SIP101295    0.09
# SIP100308    0.09
# Name: proportion, Length: 1095, dtype: float64
#
# musteri_id
# MUS1433    0.82
# MUS1360    0.64
# MUS1289    0.64
# MUS1072    0.55
# MUS1177    0.55
#            ...
# MUS1443    0.09
# MUS1335    0.09
# MUS1375    0.09
# MUS1239    0.09
# MUS1088    0.09
# Name: proportion, Length: 411, dtype: float64
#
# siparis_tarihi
# 2025-01-09 13:12:00    0.18
# 2025-04-30 22:18:00    0.09
# 2025-05-06 10:33:00    0.09
# 2025-04-02 08:16:00    0.09
# 2025-07-08 14:48:00    0.09
#                        ...
# 2024-12-19 19:50:00    0.09
# 2024-06-20 20:17:00    0.09
# 2024-04-14 19:49:00    0.09
# 2025-04-16 10:53:00    0.09
# 2025-08-31 15:11:00    0.09
# Name: proportion, Length: 1094, dtype: float64
#
# sehir
# İstanbul     24.11
# Ankara       11.32
# İzmir        10.78
# Antalya       7.85
# Konya         7.03
# Bursa         6.12
# Adana         5.75
# Gaziantep     4.47
# Mersin        4.20
# Samsun        4.11
# Eskişehir     4.11
# Trabzon       4.02
# Kayseri       3.29
# Kocaeli       2.83
# Name: proportion, dtype: float64
#
# bolge
# Marmara              31.96
# İç Anadolu           25.94
# Akdeniz              17.81
# Ege                  11.32
# Karadeniz             8.40
# Güneydoğu Anadolu     4.57
# Name: proportion, dtype: float64
#
# kategori
# kitap          20.37
# kozmetik       18.26
# spor           16.99
# ev ve yasam    16.80
# ofis           14.79
# elektronik     12.79
# Name: proportion, dtype: float64
#
# urun_adi
# Suluk                   4.66
# Powerbank               4.47
# Zaman Yönetimi          4.29
# Not Tutucu              4.29
# Python Notları          4.20
# Veri Bilimi 101         4.20
# Saklama Kutusu          4.02
# İş Analitiği Rehberi    3.93
# Şampuan                 3.74
# Girişimcilik            3.74
# Yüz Temizleme Jeli      3.74
# Nemlendirici            3.74
# Kalem Seti              3.65
# Defter Seti             3.65
# Serum                   3.65
# Direnç Bandı            3.56
# Termos                  3.47
# Güneş Kremi             3.38
# Yoga Matı               3.29
# Spor Çantası            3.20
# Masa Lambası            3.20
# Mouse Pad               3.20
# Kahve Kupası            3.11
# Webcam                  3.11
# Organizer               3.01
# Bluetooth Hoparlör      2.92
# Kablosuz Kulaklık       2.28
# Dambıl Seti             2.28
# Name: proportion, dtype: float64
#
# odeme_turu
# Kredi Kartı       53.24
# Banka Kartı       15.43
# Dijital Cüzdan    13.97
# Havale/EFT        10.14
# Kapıda Ödeme       7.21
# Name: proportion, dtype: float64
#
# musteri_tipi
# Mevcut    50.96
# Yeni      37.35
# VIP       11.69
# Name: proportion, dtype: float64
#
# iade_durumu
# Hayır    91.96
# Evet      8.04
# Name: proportion, dtype: float64
#
# haftanin_gunu
# Saturday     15.43
# Tuesday      15.43
# Wednesday    14.89
# Thursday     14.34
# Sunday       13.70
# Monday       13.15
# Friday       13.06
# Name: proportion, dtype: float64

# %%
# en sık görülen kategorileri incele
for sutun in kategorik_sutunlar:
  print(df[sutun].value_counts().head(3))
  print(" ")
# Out:
# siparis_id
# SIP100642    1
# SIP101125    1
# SIP100263    1
# Name: count, dtype: int64
#
# musteri_id
# MUS1433    9
# MUS1360    7
# MUS1289    7
# Name: count, dtype: int64
#
# siparis_tarihi
# 2025-01-09 13:12:00    2
# 2025-04-30 22:18:00    1
# 2025-05-06 10:33:00    1
# Name: count, dtype: int64
#
# sehir
# İstanbul    264
# Ankara      124
# İzmir       118
# Name: count, dtype: int64
#
# bolge
# Marmara       350
# İç Anadolu    284
# Akdeniz       195
# Name: count, dtype: int64
#
# kategori
# kitap       223
# kozmetik    200
# spor        186
# Name: count, dtype: int64
#
# urun_adi
# Suluk             51
# Powerbank         49
# Zaman Yönetimi    47
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       583
# Banka Kartı       169
# Dijital Cüzdan    153
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1007
# Evet       88
# Name: count, dtype: int64
#
# haftanin_gunu
# Saturday     169
# Tuesday      169
# Wednesday    163
# Name: count, dtype: int64

# %%
#en az görünen kategoriler
for sutun in kategorik_sutunlar:
  print(df[sutun].value_counts().tail(3))
  print(" ")
# Out:
# siparis_id
# SIP101066    1
# SIP101295    1
# SIP100308    1
# Name: count, dtype: int64
#
# musteri_id
# MUS1375    1
# MUS1239    1
# MUS1088    1
# Name: count, dtype: int64
#
# siparis_tarihi
# 2024-04-14 19:49:00    1
# 2025-04-16 10:53:00    1
# 2025-08-31 15:11:00    1
# Name: count, dtype: int64
#
# sehir
# Trabzon    44
# Kayseri    36
# Kocaeli    31
# Name: count, dtype: int64
#
# bolge
# Ege                  124
# Karadeniz             92
# Güneydoğu Anadolu     50
# Name: count, dtype: int64
#
# kategori
# ev ve yasam    184
# ofis           162
# elektronik     140
# Name: count, dtype: int64
#
# urun_adi
# Bluetooth Hoparlör    32
# Kablosuz Kulaklık     25
# Dambıl Seti           25
# Name: count, dtype: int64
#
# odeme_turu
# Dijital Cüzdan    153
# Havale/EFT        111
# Kapıda Ödeme       79
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1007
# Evet       88
# Name: count, dtype: int64
#
# haftanin_gunu
# Sunday    150
# Monday    144
# Friday    143
# Name: count, dtype: int64

# %%
# belirli sütunlar üzerinde detaylı kategorik analiz
detayli_analiz_sutunlari = ["sehir" , "kategori" , "odeme_turu" , "musteri_tipi"]
for sutun in detayli_analiz_sutunlari:
  if sutun in df.columns:
    print("Frekanslar : ")
    print(df[sutun].value_counts())

    print("Oranlar : ")
    print((df[sutun].value_counts(normalize = True)*100).round(2))
# Out:
# Frekanslar :
# sehir
# İstanbul     264
# Ankara       124
# İzmir        118
# Antalya       86
# Konya         77
# Bursa         67
# Adana         63
# Gaziantep     49
# Mersin        46
# Samsun        45
# Eskişehir     45
# Trabzon       44
# Kayseri       36
# Kocaeli       31
# Name: count, dtype: int64
# Oranlar :
# sehir
# İstanbul     24.11
# Ankara       11.32
# İzmir        10.78
# Antalya       7.85
# Konya         7.03
# Bursa         6.12
# Adana         5.75
# Gaziantep     4.47
# Mersin        4.20
# Samsun        4.11
# Eskişehir     4.11
# Trabzon       4.02
# Kayseri       3.29
# Kocaeli       2.83
# Name: proportion, dtype: float64
# Frekanslar :
# kategori
# kitap          223
# kozmetik       200
# spor           186
# ev ve yasam    184
# ofis           162
# elektronik     140
# Name: count, dtype: int64
# Oranlar :
# kategori
# kitap          20.37
# kozmetik       18.26
# spor           16.99
# ev ve yasam    16.80
# ofis           14.79
# elektronik     12.79
# Name: proportion, dtype: float64
# Frekanslar :
# odeme_turu
# Kredi Kartı       583
# Banka Kartı       169
# Dijital Cüzdan    153
# Havale/EFT        111
# Kapıda Ödeme       79
# Name: count, dtype: int64
# Oranlar :
# odeme_turu
# Kredi Kartı       53.24
# Banka Kartı       15.43
# Dijital Cüzdan    13.97
# Havale/EFT        10.14
# Kapıda Ödeme       7.21
# Name: proportion, dtype: float64
# Frekanslar :
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
# Oranlar :
# musteri_tipi
# Mevcut    50.96
# Yeni      37.35
# VIP       11.69
# Name: proportion, dtype: float64

# %%
# grafikselleştirilmesi
for sutun in detayli_analiz_sutunlari:
  if sutun in df.columns:
    plt.figure(figsize = (6,3))
    sns.countplot(data = df , x = sutun , order = df[sutun].value_counts().index)
    plt.title(f"{sutun} sütunu için count plot")
    plt.xlabel(sutun)
    plt.ylabel("Frekans")
    plt.xticks(rotation = 45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #Sayısal Veri Analizi
#
# Amaç:
#
#     Veri setindeki analiz için uygun sayısal sütunları incelemek
#     Temel istatistikler ve histogram ile dağılım yapısını değerlendirmek
#
# Adımlar:
#
#     Veri setini yüklemek
#     Sayısal sütunları belirlemek
#     Analiz için uygun sayısal sütunları seçmek
#     Seçilen sütunların genel bilgisini incelemek
#     Temel istatistikleri hesapla
#     Histogram çizdir

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("e_ticaret_veri_seti_temizlendi.csv")

# %%
sayisal_sutunlar = df.select_dtypes(include = ["int64","float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
# analiz için uygun sayısal sütunlar
analiz_sutunlari = ["birim_fiyat" ,"toplam_tutar", "teslimat_gunu" ,"musteri_puani"]

# %%
# seçilen sütunların genel bilgisi
for sutun in analiz_sutunlari:
  if sutun in df.columns:
    print(f"Sütun adı = {sutun}")
    print(f"Veri tipi = {df[sutun].dtype}")
    print(f"Benzersiz değer sayısı = {df[sutun].nunique()}")
    print()
# Out:
# Sütun adı = birim_fiyat
# Veri tipi = float64
# Benzersiz değer sayısı = 1080
#
# Sütun adı = toplam_tutar
# Veri tipi = float64
# Benzersiz değer sayısı = 1092
#
# Sütun adı = teslimat_gunu
# Veri tipi = float64
# Benzersiz değer sayısı = 7
#
# Sütun adı = musteri_puani
# Veri tipi = float64
# Benzersiz değer sayısı = 3

# %%
# temel istatistikleri hesapla
df[analiz_sutunlari].describe()
# Out:
#        birim_fiyat  toplam_tutar  teslimat_gunu  musteri_puani
# count  1095.000000   1095.000000    1095.000000    1095.000000
# mean    436.698950    779.359014       3.315068       4.282192
# std     363.625045    631.014875       1.441834       0.707625
# min      93.110000     89.680000       1.000000       3.000000
# 25%     192.955000    294.815000       2.000000       4.000000
# 50%     262.050000    565.580000       3.000000       4.000000
# 75%     583.895000   1017.895000       4.000000       5.000000
# max    1742.850000   2990.840000       7.000000       5.000000

# %%
# histogram
for sutun in analiz_sutunlari:
  if sutun in df.columns:
    plt.figure(figsize = (6,3))
    plt.hist(df[sutun], bins = 30)
    plt.title(f"{sutun} sütununa ait histogram")
    plt.xlabel(sutun)
    plt.ylabel("frekans")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Grup Bazlı Analiz
#
# Amaç:
#
#     Veri setini farklı kırılımlara ayırarak grup bazlı analiz yapalım
#     groupby yapısı ile özet istatistikler üretip sonuçları yorumlamak
#
# Adımlar:
#
#     Veri setini yüklemek
#     Grup bazlı analiz için kullanılacak sütunları belirle
#     Kategoriye göre temel analiz
#     Şehre göre temel analiz
#     Müşteri tipine göre temel analiz
#     Ödeme türüne göre temel analiz
#     Birden fazla sütun ile grup bazlı analiz

# %%
import pandas as pd

# %%
df = pd.read_csv("e_ticaret_veri_seti_temizlendi.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id       siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391  2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008  2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291  2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147  2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447  2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu
# 0          2024            1            13      Saturday
# 1          2024            8            10      Saturday
# 2          2024            8            19        Monday
# 3          2025            8             9      Saturday
# 4          2024            7            30       Tuesday

# %%
kategori_analizi = df.groupby("kategori").agg(
    {
        "toplam_tutar" : ["count" , "mean" , "sum"],
        "birim_fiyat" : ["mean"]
    }

).round(1)
kategori_analizi
# Out:
#             toplam_tutar                   birim_fiyat
#                    count    mean       sum        mean
# kategori
# elektronik           140  1520.9  212930.3      1065.5
# ev ve yasam          184   773.6  142335.6       366.7
# kitap                223   511.5  114075.6       224.8
# kozmetik             200   737.6  147522.9       373.6
# ofis                 162   290.4   47051.9       138.2
# spor                 186  1018.7  189481.9       614.5

# %%
sehire_gore = df.groupby("sehir").agg(
    {
        "toplam_tutar" : ["sum" , "mean"],
        "teslimat_gunu" : "mean",
        "musteri_puani" : "mean"
    }
).round(1)
sehire_gore
# Out:
#           toplam_tutar        teslimat_gunu musteri_puani
#                    sum   mean          mean          mean
# sehir
# Adana          50353.3  799.3           3.5           4.3
# Ankara         96721.1  780.0           3.1           4.2
# Antalya        63712.8  740.8           3.5           4.3
# Bursa          46782.8  698.3           3.5           4.2
# Eskişehir      37550.0  834.4           3.2           4.2
# Gaziantep      35240.3  719.2           3.4           4.3
# Kayseri        24878.8  691.1           3.6           4.3
# Kocaeli        21293.0  686.9           3.3           4.2
# Konya          59424.3  771.7           3.3           4.4
# Mersin         38043.9  827.0           3.5           4.2
# Samsun         36263.5  805.9           3.3           4.4
# Trabzon        30395.2  690.8           3.4           4.2
# İstanbul      224020.6  848.6           3.3           4.4
# İzmir          88718.5  751.9           3.1           4.2

# %% [markdown]
# # Pivot Tablo Analizi
#
# Amaç:
#
#     Veri setini iki yönli kırılımlar ile özetleyerek pivot tablo mantığını kavramak
#     Pivot tablo ile karşılaştırmalı analizler ve sonuçların yorumlanması
#
# Adımlar:
#
#     veri setini yükle
#     Kategori ve müşteri tipine göre pivot tablo analizi
#     Şehir ve ödeme türüne göre pivot tablo analizi
#     Kategori ve ödeme türüne göre pivot tablo analizi
#     Şehir ve müşteri tipine göre pivot tablo analizi

# %%
import pandas as pd

# %%
df = pd.read_csv("e_ticaret_veri_seti_temizlendi.csv")

# %%
#kategori ve müsteri tipine göre pivot tablo analizi
pivot_kategori = pd.pivot_table(
    df,
    index = "kategori",
    columns = "musteri_tipi",
    values = "toplam_tutar",
    aggfunc = "mean"
).round(1)
pivot_kategori
# Out:
# musteri_tipi  Mevcut     VIP    Yeni
# kategori
# elektronik    1592.5  1392.6  1451.1
# ev ve yasam    798.0   837.7   716.6
# kitap          481.4   577.9   530.4
# kozmetik       720.0   725.9   775.9
# ofis           276.4   252.7   310.7
# spor          1002.5  1264.1   981.1

# %%
pivot_sehir_odemeturu = pd.pivot_table(
    df,
    index = "sehir",
    columns = "odeme_turu",
    values = "toplam_tutar",
    aggfunc = "sum"
).round(1)
pivot_sehir_odemeturu
# Out:
# odeme_turu  Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  Kredi Kartı
# sehir
# Adana            9186.0          9134.0      5565.5        2466.4      24001.3
# Ankara          13764.1         13798.7     12892.8        7329.5      48936.1
# Antalya         10871.3          7115.7      6658.0        5511.6      33556.2
# Bursa            3694.8          8030.9      5853.7        6095.0      23108.3
# Eskişehir        4313.3          8010.6       707.9        3395.3      21122.9
# Gaziantep        4930.2          7119.0      3746.8        1395.0      18049.3
# Kayseri          2957.4          2655.7      6466.2        3307.6       9491.8
# Kocaeli          1579.2          5792.3      2891.3        2839.0       8191.2
# Konya           15601.8          9379.3      4163.0        2611.8      27668.4
# Mersin           9461.5          4307.8      2454.0         153.2      21667.4
# Samsun           5068.7          9928.5      3619.5         177.3      17469.5
# Trabzon          6164.2          2179.8      4533.4           NaN      17517.8
# İstanbul        45163.2         28373.6     24956.5        5937.2     119590.0
# İzmir           10255.4         14085.4      8385.8        6894.2      49097.9

# %%
pivot_kategori_odeme = pd.pivot_table(
    df,
    index = "kategori",
    columns = "odeme_turu",
    values = "musteri_puani",
    aggfunc = "mean"
).round(2)
pivot_kategori_odeme
# Out:
# odeme_turu   Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  \
# kategori
# elektronik          4.04            4.25        4.28          4.43
# ev ve yasam         4.16            4.23        4.00          4.21
# kitap               4.25            4.22        4.00          4.62
# kozmetik            4.48            4.33        4.36          4.53
# ofis                4.29            4.15        4.30          4.31
# spor                4.20            4.39        4.07          4.15
#
# odeme_turu   Kredi Kartı
# kategori
# elektronik          4.28
# ev ve yasam         4.36
# kitap               4.27
# kozmetik            4.41
# ofis                4.23
# spor                4.28

# %% [markdown]
# # Veri Görselleştirme
#
# Amaç:
#
#     Veri setindeki farklı değişkenleri uygun grafik türüyle görselleştirmek
#     Grafikler üzerinden zaman değişimi, ilişki, karşılaştırma ve dağılım yapısını incelemek
#
# Adımlar:
#
#     Veri setini yüklemek
#     Line plot ile zaman içindeki değişimi görselleştirmek
#     Scatter plot ile iki sayısal değişken arasındaki ilişkiyi görselleştirmek
#     Bar plot ile karşılaştırmalı görselleştirme yapmak
#     Histogram ile sayısal dağılım görselleştirmek
#     Box plot ile dağılım ve aykırı değer tespiti

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %%
df = pd.read_csv("e_ticaret_veri_seti_temizlendi.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id       siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391  2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008  2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291  2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147  2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447  2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu
# 0          2024            1            13      Saturday
# 1          2024            8            10      Saturday
# 2          2024            8            19        Monday
# 3          2025            8             9      Saturday
# 4          2024            7            30       Tuesday

# %%
# line plot
df["siparis_tarihi"] = pd.to_datetime(df["siparis_tarihi"])
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id      siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391 2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008 2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291 2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147 2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447 2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu
# 0          2024            1            13      Saturday
# 1          2024            8            10      Saturday
# 2          2024            8            19        Monday
# 3          2025            8             9      Saturday
# 4          2024            7            30       Tuesday

# %%
aylik_toplam_tutar = df.groupby("siparis_ayi")["toplam_tutar"].sum().reset_index()
aylik_toplam_tutar
# Out:
#     siparis_ayi  toplam_tutar
# 0             1      68309.45
# 1             2      67984.01
# 2             3      70857.89
# 3             4      68630.39
# 4             5      92213.41
# 5             6      77526.88
# 6             7      68774.62
# 7             8      55945.11
# 8             9      80591.62
# 9            10      60860.45
# 10           11      62337.84
# 11           12      79366.45

# %%
plt.figure(figsize = (6,3))
plt.plot(aylik_toplam_tutar["siparis_ayi"], aylik_toplam_tutar , marker = "o")
plt.title("Aylara göre toplam tutar")
plt.xlabel("aylar")
plt.ylabel("toplam tutar")
plt.xticks(aylik_toplam_tutar["siparis_ayi"])
plt.tight_layout()
plt.show()

# %% [markdown]
# # ZAMAN SERİSİ ANALİZİ

# %%
import pandas as pd
df = pd.read_csv("e_ticaret_veri_seti_temizlendi.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id       siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391  2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008  2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291  2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147  2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447  2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu
# 0          2024            1            13      Saturday
# 1          2024            8            10      Saturday
# 2          2024            8            19        Monday
# 3          2025            8             9      Saturday
# 4          2024            7            30       Tuesday

# %%
df["siparis_tarihi"] = pd.to_datetime(df["siparis_tarihi"])

# %%
df["siparis_yili"] = df["siparis_tarihi"].dt.year
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df["siparis_gunu"] = df["siparis_tarihi"].dt.day
df["haftanin_gunu"] = df["siparis_tarihi"].dt.day_name()
df["hafta_numarasi"] = df["siparis_tarihi"].dt.isocalendar().week.astype(int)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id      siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391 2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008 2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291 2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147 2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447 2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu  hafta_numarasi
# 0          2024            1            13      Saturday               2
# 1          2024            8            10      Saturday              32
# 2          2024            8            19        Monday              34
# 3          2025            8             9      Saturday              32
# 4          2024            7            30       Tuesday              31

# %%
#aylara göre
aylik_yogunluk = (
    df.groupby("siparis_ayi")
    .agg(
        siparis_sayisi = ("siparis_id", "count"),
        benzersiz_musteri_sayisi = ("musteri_id", "nunique")
    )
    .reset_index()
    .sort_values("siparis_ayi")
)
aylik_yogunluk
# Out:
#     siparis_ayi  siparis_sayisi  benzersiz_musteri_sayisi
# 0             1              97                        89
# 1             2              84                        75
# 2             3              94                        81
# 3             4             111                        94
# 4             5             102                        94
# 5             6              85                        77
# 6             7              79                        71
# 7             8              80                        71
# 8             9              91                        83
# 9            10              89                        80
# 10           11              86                        77
# 11           12              97                        88

# %%
df["ay_donemi"] = df["siparis_gunu"].apply(
    lambda x: "Ayın ilk yarısı" if x <= 15 else "Ayın ikinci yarısı"
)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id      siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391 2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008 2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291 2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147 2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447 2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu  hafta_numarasi  \
# 0          2024            1            13      Saturday               2
# 1          2024            8            10      Saturday              32
# 2          2024            8            19        Monday              34
# 3          2025            8             9      Saturday              32
# 4          2024            7            30       Tuesday              31
#
#             ay_donemi
# 0     Ayın ilk yarısı
# 1     Ayın ilk yarısı
# 2  Ayın ikinci yarısı
# 3     Ayın ilk yarısı
# 4  Ayın ikinci yarısı

# %%
ay_donemi_analiz = (
    df.groupby("ay_donemi")
    .agg(
        toplam_tutar = ("toplam_tutar" , "sum")
    )
    .round(1)
    .reset_index()
)
ay_donemi_analiz
# Out:
#             ay_donemi  toplam_tutar
# 0  Ayın ikinci yarısı      413476.0
# 1     Ayın ilk yarısı      439922.1

# %%
df["hafta_tipi"] = df["siparis_tarihi"].dt.dayofweek.apply(
    lambda x: "hafta sonu" if x >= 5 else "hafta içi"
)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id      siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391 2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008 2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291 2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147 2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447 2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu  hafta_numarasi  \
# 0          2024            1            13      Saturday               2
# 1          2024            8            10      Saturday              32
# 2          2024            8            19        Monday              34
# 3          2025            8             9      Saturday              32
# 4          2024            7            30       Tuesday              31
#
#             ay_donemi  hafta_tipi
# 0     Ayın ilk yarısı  hafta sonu
# 1     Ayın ilk yarısı  hafta sonu
# 2  Ayın ikinci yarısı   hafta içi
# 3     Ayın ilk yarısı  hafta sonu
# 4  Ayın ikinci yarısı   hafta içi

# %%
hafta_analizi = (
    df.groupby("hafta_tipi")
    .agg(
        ortalama_siparis_tutari = ("toplam_tutar" , "mean"),
    )
    .round(1)
    .reset_index()
)
hafta_analizi
# Out:
#    hafta_tipi  ortalama_siparis_tutari
# 0   hafta içi                    784.4
# 1  hafta sonu                    767.1

# %% [markdown]
#  # Değişkenler Arası İlişkiler
#
#   1. veri setini yükle
#   2. sayisal sütunları belirle
#   3. korelasyon matrisini oluştur
#   4. korelasyon matrisini heatmap ile görselleştir

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("e_ticaret_veri_seti_temizlendi.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id       siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391  2024-01-13 17:06:00
# 1             3           3  SIP100263    MUS1008  2024-08-10 15:13:00
# 2             4           4  SIP100707    MUS1291  2024-08-19 08:24:00
# 3             5           5  SIP100687    MUS1147  2025-08-09 08:42:00
# 4            10          10  SIP100254    MUS1447  2024-07-30 09:06:00
#
#        sehir              bolge    kategori            urun_adi  adet  \
# 0   İstanbul            Marmara    kozmetik        Nemlendirici     1
# 1    Antalya            Akdeniz       kitap        Girişimcilik     5
# 2  Gaziantep  Güneydoğu Anadolu  elektronik           Powerbank     3
# 3      Konya         İç Anadolu    kozmetik        Nemlendirici     2
# 4      Konya         İç Anadolu  elektronik  Bluetooth Hoparlör     1
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 2       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
# 3       417.02           0.00          59.9  Dijital Cüzdan       Mevcut
# 4      1327.75           0.05          29.9     Banka Kartı       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            3.0            5.0       Hayır            0.250       1023.80
# 2            4.0            5.0       Hayır            0.280       2439.03
# 3            4.0            5.0       Hayır            0.220        893.94
# 4            4.0            5.0       Hayır            0.283       1291.26
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanin_gunu
# 0          2024            1            13      Saturday
# 1          2024            8            10      Saturday
# 2          2024            8            19        Monday
# 3          2025            8             9      Saturday
# 4          2024            7            30       Tuesday

# %%
sayisal_sutunlar = df.select_dtypes(include = ["int64" , "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
korelasyon = df[sayisal_sutunlar].corr()
korelasyon
# Out:
#                  Unnamed: 0.1  Unnamed: 0      adet  birim_fiyat  \
# Unnamed: 0.1         1.000000    0.999987  0.023288     0.019535
# Unnamed: 0           0.999987    1.000000  0.023024     0.019482
# adet                 0.023288    0.023024  1.000000    -0.172071
# birim_fiyat          0.019535    0.019482 -0.172071     1.000000
# indirim_orani       -0.010931   -0.011015  0.016591    -0.002181
# kargo_ucreti        -0.012549   -0.012665  0.033094     0.019820
# teslimat_gunu       -0.029585   -0.029701  0.001184    -0.005320
# musteri_puani       -0.021654   -0.021415 -0.008471     0.009712
# kar_marji_orani      0.021666    0.021525 -0.000069    -0.008091
# toplam_tutar         0.033482    0.033328  0.431589     0.715181
# siparis_yili         0.013135    0.013078  0.029008    -0.028609
# siparis_ayi         -0.040504   -0.040709  0.072723    -0.029080
# siparis_gunu        -0.003342   -0.003318 -0.003461    -0.033501
#
#                  indirim_orani  kargo_ucreti  teslimat_gunu  musteri_puani  \
# Unnamed: 0.1         -0.010931     -0.012549      -0.029585      -0.021654
# Unnamed: 0           -0.011015     -0.012665      -0.029701      -0.021415
# adet                  0.016591      0.033094       0.001184      -0.008471
# birim_fiyat          -0.002181      0.019820      -0.005320       0.009712
# indirim_orani         1.000000     -0.005396       0.059778       0.008851
# kargo_ucreti         -0.005396      1.000000      -0.007760       0.025023
# teslimat_gunu         0.059778     -0.007760       1.000000       0.015807
# musteri_puani         0.008851      0.025023       0.015807       1.000000
# kar_marji_orani      -0.009713     -0.000559       0.007860      -0.014840
# toplam_tutar         -0.029132      0.033540       0.003866       0.011660
# siparis_yili          0.027660      0.078653       0.038177      -0.044280
# siparis_ayi           0.026244     -0.013895       0.002053      -0.055970
# siparis_gunu          0.016658      0.001687      -0.023197      -0.032129
#
#                  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# Unnamed: 0.1            0.021666      0.033482      0.013135    -0.040504
# Unnamed: 0              0.021525      0.033328      0.013078    -0.040709
# adet                   -0.000069      0.431589      0.029008     0.072723
# birim_fiyat            -0.008091      0.715181     -0.028609    -0.029080
# indirim_orani          -0.009713     -0.029132      0.027660     0.026244
# kargo_ucreti           -0.000559      0.033540      0.078653    -0.013895
# teslimat_gunu           0.007860      0.003866      0.038177     0.002053
# musteri_puani          -0.014840      0.011660     -0.044280    -0.055970
# kar_marji_orani         1.000000     -0.007492     -0.030443     0.042821
# toplam_tutar           -0.007492      1.000000     -0.006989     0.018804
# siparis_yili           -0.030443     -0.006989      1.000000     0.047170
# siparis_ayi             0.042821      0.018804      0.047170     1.000000
# siparis_gunu           -0.031069     -0.032507     -0.032772    -0.029934
#
#                  siparis_gunu
# Unnamed: 0.1        -0.003342
# Unnamed: 0          -0.003318
# adet                -0.003461
# birim_fiyat         -0.033501
# indirim_orani        0.016658
# kargo_ucreti         0.001687
# teslimat_gunu       -0.023197
# musteri_puani       -0.032129
# kar_marji_orani     -0.031069
# toplam_tutar        -0.032507
# siparis_yili        -0.032772
# siparis_ayi         -0.029934
# siparis_gunu         1.000000

# %%
sns.heatmap(korelasyon , annot = True , fmt = ".1f" , cmap = "coolwarm" , linewidth = 0.5)
plt.title("Korelasyon")
# Out:
# Text(0.5, 1.0, 'Korelasyon')
